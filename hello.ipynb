# %% [markdown]
# # My First Notebook
# This is a short paragraph exploring the basics of Jupyter. It is a powerful tool for data science.

# %% [markdown]
# ## About this Project
# I am learning how to structure notebooks with different cell types.
#
# ### Goals
# * Create a file
# * Use Markdown
# * Run Python code

# %%
print("Hello, world!")
name = "User"
print(f"Welcome to your first notebook, {name}.")
# Out:
# Hello, world!
# Welcome to your first notebook, User.

# %% [raw]
# Thnak you m4ace
